# %% [markdown]
# # Getting Started
#
# This is a minimal Jupyter notebook included by the template.
#
# - The Python environment is provided by Nix.
# - An isolated virtualenv (.venv) is managed automatically via direnv.
#
# Try running the code cell below.

# %%
print("Hello from the skeletal Jupyter notebook!")
